# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ## p_o2 from 10^0 to 10^3 x r_Tnef from 10^-3 to 10^1
# Later realised that o2 levels dont go upto threshold levels

# %%
#Input parms
p_o2_arr=np.logspace(0,3,10) #10 values bw 10^0 to 10^3
r_Tneg_arr=np.logspace(-3,1,10) #10 values bw 10^-3 to 10^1
p_o2_arr=p_o2_arr[:-1]

# %% [markdown]
# ### OG Equation

# %%
lis=[]
for p_o2 in p_o2_arr:
    for r_Tneg in r_Tneg_arr:
        df=pd.read_csv("../raw_output/EnvEq/singlecelltype/Tneg/p_o2-r_Tneg/"+"{:.2E}".format(p_o2)+'-'+"{:.2E}".format(r_Tneg)+'.csv')
        lis.append([p_o2,r_Tneg,df.o2.iloc[-1],df.Tneg.iloc[-1]])

# %%
df1=pd.DataFrame(lis,columns=['po2','r_Tneg','o2_eq','Tneg_eq'])
df1.to_csv('../analysed_data/EnvEq/singlecelltype/Tneg/p_o2-r_Tneg/eq_values.csv',index=False)

# %% [markdown]
# ### Alt Equation

# %%
lis=[]
for p_o2 in p_o2_arr:
    for r_Tneg in r_Tneg_arr:
        df=pd.read_csv("../raw_output/EnvEq_Alt/singlecelltype/Tneg/p_o2-r_Tneg/"+"{:.2E}".format(p_o2)+'-'+"{:.2E}".format(r_Tneg)+'.csv')
        lis.append([p_o2,r_Tneg,df.o2.iloc[-1],df.Tneg.iloc[-1]])

# %%
df2=pd.DataFrame(lis,columns=['po2','r_Tneg','o2_eq','Tneg_eq'])
df2.to_csv('../analysed_data/EnvEq_Alt/singlecelltype/Tneg/p_o2-r_Tneg/eq_values.csv',index=False)

# %% [markdown]
# ## p_o2 from 10^3 to 10^6 x r_Tnef from 10^-3 to 10^1
# cant compare with previous data as o2 inital is different

# %%
#Input parms
p_o2_arr=np.logspace(3,6,10) #10 values bw 10^3 to 10^4
r_Tneg_arr=np.logspace(-3,1,10) #10 values bw 10^-3 to 10^1

# %% [markdown]
# ### OG Equation

# %%
lis=[]
for p_o2 in p_o2_arr:
    for r_Tneg in r_Tneg_arr:
        df=pd.read_csv("../raw_output/EnvEq/singlecelltype/Tneg/p_o2-r_Tneg/"+"{:.2E}".format(p_o2)+'-'+"{:.2E}".format(r_Tneg)+'.csv')
        lis.append([p_o2,r_Tneg,df.o2.iloc[-1],df.Tneg.iloc[-1]])

# %%
df3=pd.DataFrame(lis,columns=['po2','r_Tneg','o2_eq','Tneg_eq'])
df3.to_csv('../analysed_data/EnvEq/singlecelltype/Tneg/p_o2-r_Tneg/eq_values-ext.csv',index=False)

# %% [markdown]
# ### Alt Equation

# %%
lis=[]
for p_o2 in p_o2_arr:
    for r_Tneg in r_Tneg_arr:
        df=pd.read_csv("../raw_output/EnvEq_Alt/singlecelltype/Tneg/p_o2-r_Tneg/"+"{:.2E}".format(p_o2)+'-'+"{:.2E}".format(r_Tneg)+'.csv')
        lis.append([p_o2,r_Tneg,df.o2.iloc[-1],df.Tneg.iloc[-1]])

# %%
df4=pd.DataFrame(lis,columns=['po2','r_Tneg','o2_eq','Tneg_eq'])
df4.to_csv('../analysed_data/EnvEq_Alt/singlecelltype/Tneg/p_o2-r_Tneg/eq_values-ext.csv',index=False)

# %% [markdown]
# ## p_o2 @ 10^3 x r_Tnef from 4.62E-4 to 1E-3
# Some linear space exploration for OG equation

# %%
#Input parms
p_o2_arr=np.logspace(3,3,1) #Just 10^3
r_Tneg_arr=np.linspace(4.62E-4,1E-3,10) #10 values bw 4.62E-4 to 1E-3

# %%
lis=[]
for p_o2 in p_o2_arr:
    for r_Tneg in r_Tneg_arr:
        df=pd.read_csv("../raw_output/EnvEq/singlecelltype/Tneg/p_o2-r_Tneg/"+"{:.2E}".format(p_o2)+'-'+"{:.2E}".format(r_Tneg)+'.csv')
        lis.append([p_o2,r_Tneg,df.o2.iloc[-1],df.Tneg.iloc[-1]])

# %%
df5=pd.DataFrame(lis,columns=['po2','r_Tneg','o2_eq','Tneg_eq'])
df5.to_csv('../analysed_data/EnvEq/singlecelltype/Tneg/p_o2-r_Tneg/eq_values-lin.csv',index=False)

# %% [markdown]
# ## p_o2 @ 2500 to 4500 x r_Tnef from 0.001 to 0.02
# Some linear space exploration for Alt equation

# %%
p_o2_arr=np.linspace(2500,4500,10) #10 values b/w 2500 to 4500
r_Tneg_arr=np.linspace(0.001,0.02,5) #5 values b/w 0.001 to 0.02

# %%
lis=[]
for p_o2 in p_o2_arr:
    for r_Tneg in r_Tneg_arr:
        df=pd.read_csv("../raw_output/EnvEq_Alt/singlecelltype/Tneg/p_o2-r_Tneg/"+"{:.2E}".format(p_o2)+'-'+"{:.2E}".format(r_Tneg)+'.csv')
        lis.append([p_o2,r_Tneg,df.o2.iloc[-1],df.Tneg.iloc[-1]])

# %%
df6=pd.DataFrame(lis,columns=['po2','r_Tneg','o2_eq','Tneg_eq'])
df6.to_csv('../analysed_data/EnvEq_Alt/singlecelltype/Tneg/p_o2-r_Tneg/eq_values-lin.csv',index=False)

# %% [markdown]
# ## Looking at analysed data

# %% [markdown]
# ### Alt Equation (extended)
# po2 10^3 to 10^6 considered, <10^3 doesnt satisfy the conditions

# %%
df4=pd.read_csv('../analysed_data/EnvEq_Alt/singlecelltype/Tneg/p_o2-r_Tneg/eq_values-ext.csv')

# %%
df4=df4[(df4.Tneg_eq>1)&(df4.o2_eq>6750)&(df4.o2_eq<47250)] #taking values only when Tneg is non zero at eq and o2 is inbetween thresholds
df4.to_csv('../analysed_data/EnvEq_Alt/singlecelltype/Tneg/p_o2-r_Tneg/eq_values-satifactory.csv',index=False)
df4
# Out:
#                po2    r_Tneg         o2_eq       Tneg_eq
# 20     4641.588834  0.001000  28538.383793  5.107132e+08
# 21     4641.588834  0.002783  40514.895449  1.681676e+08
# 22     4641.588834  0.007743  44791.192093  4.506607e+07
# 23     4641.588834  0.021544  46418.532577  7.277330e+05
# 30    10000.000000  0.001000  28503.941990  2.041872e+09
# 31    10000.000000  0.002783  40567.143008  1.699257e+09
# 32    10000.000000  0.007743  44854.621125  1.576131e+09
# 33    10000.000000  0.021544  46337.733620  1.531976e+09
# 34    10000.000000  0.059948  46949.050545  1.516203e+09
# 35    10000.000000  0.166810  47236.114819  1.505141e+09
# 36    10000.000000  0.464159  47208.664804  1.506161e+09
# 37    10000.000000  1.291550  47149.062444  1.512865e+09
# 38    10000.000000  3.593814  47193.692923  1.511300e+09
# 40    21544.346900  0.001000  28496.751614  5.340195e+09
# 41    21544.346900  0.002783  40478.108794  4.997779e+09
# 42    21544.346900  0.007743  44816.330507  4.874819e+09
# 43    21544.346900  0.021544  46354.232326  4.833812e+09
# 44    21544.346900  0.059948  46922.251340  4.810897e+09
# 45    21544.346900  0.166810  47134.294284  4.811459e+09
# 48    21544.346900  3.593814  47196.909410  4.815140e+09
# 50    46415.888336  0.001000  28482.696646  1.244633e+10
# 51    46415.888336  0.002783  40526.987153  1.210338e+10
# 52    46415.888336  0.007743  44836.135413  1.198018e+10
# 53    46415.888336  0.021544  46342.811081  1.193859e+10
# 54    46415.888336  0.059948  46821.582396  1.192084e+10
# 56    46415.888336  0.464159  47021.049985  1.191393e+10
# 60   100000.000000  0.001000  28577.667889  2.775566e+10
# 61   100000.000000  0.002783  40520.110429  2.741223e+10
# 62   100000.000000  0.007743  44823.047882  2.729207e+10
# 63   100000.000000  0.021544  46152.059924  2.728233e+10
# 64   100000.000000  0.059948  46823.980827  2.722468e+10
# 65   100000.000000  0.166810  46943.427059  2.721977e+10
# 66   100000.000000  0.464159  47215.800784  2.720767e+10
# 67   100000.000000  1.291550  47197.046491  2.725494e+10
# 70   215443.469003  0.001000  28550.932174  6.073944e+10
# 71   215443.469003  0.002783  40558.152897  6.039614e+10
# 72   215443.469003  0.007743  44772.466186  6.022861e+10
# 73   215443.469003  0.021544  45815.227611  6.031111e+10
# 74   215443.469003  0.059948  46945.631201  6.021808e+10
# 76   215443.469003  0.464159  47095.963495  5.994242e+10
# 80   464158.883361  0.001000  28540.825549  1.318016e+11
# 81   464158.883361  0.002783  40380.346841  1.314602e+11
# 82   464158.883361  0.007743  44372.519691  1.313431e+11
# 83   464158.883361  0.021544  45967.026918  1.313195e+11
# 84   464158.883361  0.059948  46614.926449  1.313176e+11
# 90  1000000.000000  0.001000  28484.572076  2.848948e+11
# 91  1000000.000000  0.002783  40758.023249  2.845541e+11
# 92  1000000.000000  0.007743  44490.649517  2.844948e+11
# 93  1000000.000000  0.021544  46013.040083  2.844946e+11
# 94  1000000.000000  0.059948  46951.107157  2.844074e+11

# %%
plt.scatter(df4.po2,df4.o2_eq,c=df4.r_Tneg)
plt.xlabel('po2 (nmol/min)')
plt.ylabel('o2_eq (nmol)')
plt.savefig('../figures/EnvEq_Alt/singlecelltype/Tneg/p_o2-r_Tneg/o2eq-v-po2.svg')
# Out:
# &lt;Figure size 432x288 with 1 Axes&gt;

# %%
plt.scatter(df4.r_Tneg,df4.o2_eq,c=df4.po2)
plt.xlabel('r_Tneg (/min)')
plt.ylabel('o2_eq (nmol)')
plt.savefig('../figures/EnvEq_Alt/singlecelltype/Tneg/p_o2-r_Tneg/o2eq-v-rTneg.svg')
# Out:
# &lt;Figure size 432x288 with 1 Axes&gt;

# %%
plt.scatter(df4.po2,df4.Tneg_eq,c=df4.r_Tneg)
plt.xlabel('po2 (nmol/min)')
plt.ylabel('Tneg_eq')
plt.savefig('../figures/EnvEq_Alt/singlecelltype/Tneg/p_o2-r_Tneg/Tnegeq-v-po2.svg')
# Out:
# &lt;Figure size 432x288 with 1 Axes&gt;

# %%
plt.scatter(df4.r_Tneg,df4.Tneg_eq,c=df4.po2)
plt.xlabel('r_Tneg (/min)')
plt.ylabel('Tneg_eq')
plt.savefig('../figures/EnvEq_Alt/singlecelltype/Tneg/p_o2-r_Tneg/Tnegeq-v-rTneg.svg')
# Out:
# &lt;Figure size 432x288 with 1 Axes&gt;

# %%
df4.corr()
# Out:
#               po2    r_Tneg     o2_eq   Tneg_eq
# po2      1.000000 -0.175822 -0.086885  0.999998
# r_Tneg  -0.175822  1.000000  0.247067 -0.176319
# o2_eq   -0.086885  0.247067  1.000000 -0.089034
# Tneg_eq  0.999998 -0.176319 -0.089034  1.000000

# %% [markdown]
# ### OG Equation (extended)
# po2 10^3 to 10^6 considered, <10^3 doesnt satisfy the conditions

# %%
df3=pd.read_csv('../analysed_data/EnvEq/singlecelltype/Tneg/p_o2-r_Tneg/eq_values-ext.csv')

# %%
df3=df3[(df3.Tneg_eq>1)&(df3.o2_eq>6750)&(df3.o2_eq<47250)] #taking values only when Tneg is non zero at eq and o2 is inbetween thresholds
df3.to_csv('../analysed_data/EnvEq/singlecelltype/Tneg/p_o2-r_Tneg/eq_values-satifactory.csv',index=False)
df3
# Out:
#             po2    r_Tneg         o2_eq     Tneg_eq
# 0   1000.000000  0.001000  10005.863405  462.135202
# 1   1000.000000  0.002783  10005.873773  166.082780
# 2   1000.000000  0.007743  10005.877495   59.687057
# 3   1000.000000  0.021544  10005.878823   21.450416
# 4   1000.000000  0.059948  10005.879298    7.708880
# 5   1000.000000  0.166810  10005.879658    2.770428
# 10  2154.434690  0.001000  21569.222254  462.266870
# 11  2154.434690  0.002783  21569.232633  166.130099
# 12  2154.434690  0.007743  21569.236368   59.704062
# 13  2154.434690  0.021544  21569.237722   21.456527
# 14  2154.434690  0.059948  21569.238211    7.711076
# 15  2154.434690  0.166810  21569.238160    2.771217
# 20  4641.588834  0.001000  46411.793883  462.550558
# 21  4641.588834  0.002783  46411.804250  166.232052
# 22  4641.588834  0.007743  46411.807976   59.740702
# 23  4641.588834  0.021544  46411.809316   21.469695
# 24  4641.588834  0.059948  46411.809793    7.715808
# 25  4641.588834  0.166810  46411.809962    2.772918

# %%
df3.corr()
# Out:
#                   po2        r_Tneg         o2_eq   Tneg_eq
# po2      1.000000e+00  1.769145e-17  9.999998e-01  0.000276
# r_Tneg   1.769145e-17  1.000000e+00  1.855552e-07 -0.495201
# o2_eq    9.999998e-01  1.855552e-07  1.000000e+00  0.000276
# Tneg_eq  2.763825e-04 -4.952011e-01  2.760072e-04  1.000000

# %%
plt.scatter(df3.po2,df3.o2_eq,c=df3.r_Tneg)
plt.xlabel('po2 (nmol/min)')
plt.ylabel('o2_eq (nmol)')
plt.savefig('../figures/EnvEq/singlecelltype/Tneg/p_o2-r_Tneg/o2eq-v-po2.svg')
# Out:
# &lt;Figure size 432x288 with 1 Axes&gt;

# %%
plt.scatter(df3.r_Tneg,df3.o2_eq,c=df3.po2)
plt.xlabel('r_Tneg (/min)')
plt.ylabel('o2_eq (nmol)')
plt.savefig('../figures/EnvEq/singlecelltype/Tneg/p_o2-r_Tneg/o2eq-v-rTneg.svg')
# Out:
# &lt;Figure size 432x288 with 1 Axes&gt;

# %%
plt.scatter(df3.po2,df3.Tneg_eq,c=df3.r_Tneg)
plt.xlabel('po2 (nmol/min)')
plt.ylabel('Tneg_eq')
plt.savefig('../figures/EnvEq/singlecelltype/Tneg/p_o2-r_Tneg/Tnegeq-v-po2.svg')
# Out:
# &lt;Figure size 432x288 with 1 Axes&gt;

# %%
plt.scatter(df3.r_Tneg,df3.Tneg_eq,c=df3.po2)
plt.xlabel('r_Tneg (/min)')
plt.ylabel('Tneg_eq')
plt.savefig('../figures/EnvEq/singlecelltype/Tneg/p_o2-r_Tneg/Tnegeq-v-rTneg.svg')
# Out:
# &lt;Figure size 432x288 with 1 Axes&gt;

# %% [markdown]
# ### Alt Equation - Linear exploration

# %%
df6=pd.read_csv('../analysed_data/EnvEq_Alt/singlecelltype/Tneg/p_o2-r_Tneg/eq_values-lin.csv')

# %%
df6=df6[(df6.Tneg_eq>1)&(df6.o2_eq>6750)&(df6.o2_eq<47250)] #taking values only when Tneg is non zero at eq and o2 is inbetween thresholds
df6.to_csv('../analysed_data/EnvEq_Alt/singlecelltype/Tneg/p_o2-r_Tneg/eq_values-lin-satifactory.csv',index=False)
df6
# Out:
#             po2   r_Tneg         o2_eq       Tneg_eq
# 10  2944.444444  0.00100  28532.653132  2.585649e+07
# 15  3166.666667  0.00100  28520.291544  8.928537e+07
# 20  3388.888889  0.00100  28531.360681  1.527138e+08
# 25  3611.111111  0.00100  28562.039088  2.164265e+08
# 30  3833.333333  0.00100  28544.120200  2.798558e+08
# 35  4055.555556  0.00100  28587.106772  3.432806e+08
# 40  4277.777778  0.00100  28536.277325  4.067135e+08
# 45  4500.000000  0.00100  28549.560155  4.704262e+08
# 46  4500.000000  0.00575  43969.880872  2.871010e+07

# %%
df6.corr()
# Out:
#               po2    r_Tneg     o2_eq   Tneg_eq
# po2      1.000000  0.453743  0.455383  0.592507
# r_Tneg   0.453743  1.000000  0.999993 -0.449020
# o2_eq    0.455383  0.999993  1.000000 -0.447369
# Tneg_eq  0.592507 -0.449020 -0.447369  1.000000

# %% [markdown]
# ### OG Equation - Linear exploration

# %%
df5=pd.read_csv('../analysed_data/EnvEq/singlecelltype/Tneg/p_o2-r_Tneg/eq_values-lin.csv')

# %%
df5=df5[(df5.Tneg_eq>1)&(df5.o2_eq>6750)&(df5.o2_eq<47250)] #taking values only when Tneg is non zero at eq and o2 is inbetween thresholds
df5.to_csv('../analysed_data/EnvEq/singlecelltype/Tneg/p_o2-r_Tneg/eq_values-lin-satifactory.csv',index=False)
df5
# Out:
#       po2    r_Tneg         o2_eq      Tneg_eq
# 0  1000.0  0.000462  10005.844555  1000.292644
# 1  1000.0  0.000522  10005.848569   885.693530
# 2  1000.0  0.000582  10005.851758   794.653576
# 3  1000.0  0.000641  10005.854352   720.585034
# 4  1000.0  0.000701  10005.856504   659.146880
# 5  1000.0  0.000761  10005.858318   607.362269
# 6  1000.0  0.000821  10005.859868   563.121692
# 7  1000.0  0.000880  10005.861207   524.888543
# 8  1000.0  0.000940  10005.862376   491.516996
# 9  1000.0  0.001000  10005.863405   462.135202

# %%
df5.corr()
# Out:
#          po2    r_Tneg    o2_eq   Tneg_eq
# po2      NaN       NaN      NaN       NaN
# r_Tneg   NaN  1.000000  0.97658 -0.976581
# o2_eq    NaN  0.976580  1.00000 -1.000000
# Tneg_eq  NaN -0.976581 -1.00000  1.000000
